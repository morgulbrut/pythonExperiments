# %% [markdown]
# # QT Buttons 1
#
# Generates a bunch of buttons puts them into a layout

# %%
buttons =[]
i = 0
j = 4
no_of_butttons = 12
prefix='V'

for k in range (1,no_of_butttons+1):
    buttons.append('{}{}'.format(prefix,k))

print('\n*****************************\nButtons\n*****************************\n')


for b in buttons:
    string = 'Button *b{} = new Button(tr("{}"));\nconnect({},SIGNAL(clicked()),this,SLOT(b{}Clicked()));'.format(b,b,b,b)
    print(string)


for b in buttons:
    string = 'mainLayout->addWidget(b{}, {} , {});'.format(b,int(i/j),i%j)
    i += 1
    print(string)
    
print('\n*****************************\nSlot stubs\n*****************************\n')

for b in buttons:
    string ='void VentilsGui::b'+b+'Clicked(){\n\tqDebug()<<\"'+ b+' pressed.\";\n}'
    print(string)

print('\n*****************************\nSlot definitions\n*****************************\n')

for b in buttons:
    string ='void b'+b+'Clicked();\n'
    print(string)
# Out:
# *****************************
# Buttons
# *****************************
#
# Button *bV1 = new Button(tr("V1"));
# connect(V1,SIGNAL(clicked()),this,SLOT(bV1Clicked()));
# Button *bV2 = new Button(tr("V2"));
# connect(V2,SIGNAL(clicked()),this,SLOT(bV2Clicked()));
# Button *bV3 = new Button(tr("V3"));
# connect(V3,SIGNAL(clicked()),this,SLOT(bV3Clicked()));
# Button *bV4 = new Button(tr("V4"));
# connect(V4,SIGNAL(clicked()),this,SLOT(bV4Clicked()));
# Button *bV5 = new Button(tr("V5"));
# connect(V5,SIGNAL(clicked()),this,SLOT(bV5Clicked()));
# Button *bV6 = new Button(tr("V6"));
# connect(V6,SIGNAL(clicked()),this,SLOT(bV6Clicked()));
# Button *bV7 = new Button(tr("V7"));
# connect(V7,SIGNAL(clicked()),this,SLOT(bV7Clicked()));
# Button *bV8 = new Button(tr("V8"));
# connect(V8,SIGNAL(clicked()),this,SLOT(bV8Clicked()));
# Button *bV9 = new Button(tr("V9"));
# connect(V9,SIGNAL(clicked()),this,SLOT(bV9Clicked()));
# Button *bV10 = new Button(tr("V10"));
# connect(V10,SIGNAL(clicked()),this,SLOT(bV10Clicked()));
# Button *bV11 = new Button(tr("V11"));
# connect(V11,SIGNAL(clicked()),this,SLOT(bV11Clicked()));
# Button *bV12 = new Button(tr("V12"));
# connect(V12,SIGNAL(clicked()),this,SLOT(bV12Clicked()));
# mainLayout->addWidget(bV1, 0 , 0);
# mainLayout->addWidget(bV2, 0 , 1);
# mainLayout->addWidget(bV3, 0 , 2);
# mainLayout->addWidget(bV4, 0 , 3);
# mainLayout->addWidget(bV5, 1 , 0);
# mainLayout->addWidget(bV6, 1 , 1);
# mainLayout->addWidget(bV7, 1 , 2);
# mainLayout->addWidget(bV8, 1 , 3);
# mainLayout->addWidget(bV9, 2 , 0);
# mainLayout->addWidget(bV10, 2 , 1);
# mainLayout->addWidget(bV11, 2 , 2);
# mainLayout->addWidget(bV12, 2 , 3);
#
# *****************************
# Slot stubs
# *****************************
#
# void VentilsGui::bV1Clicked(){
# 	qDebug()<<"V1 pressed.";
# }
# void VentilsGui::bV2Clicked(){
# 	qDebug()<<"V2 pressed.";
# }
# void VentilsGui::bV3Clicked(){
# 	qDebug()<<"V3 pressed.";
# }
# void VentilsGui::bV4Clicked(){
# 	qDebug()<<"V4 pressed.";
# }
# void VentilsGui::bV5Clicked(){
# 	qDebug()<<"V5 pressed.";
# }
# void VentilsGui::bV6Clicked(){
# 	qDebug()<<"V6 pressed.";
# }
# void VentilsGui::bV7Clicked(){
# 	qDebug()<<"V7 pressed.";
# }
# void VentilsGui::bV8Clicked(){
# 	qDebug()<<"V8 pressed.";
# }
# void VentilsGui::bV9Clicked(){
# 	qDebug()<<"V9 pressed.";
# }
# void VentilsGui::bV10Clicked(){
# 	qDebug()<<"V10 pressed.";
# }
# void VentilsGui::bV11Clicked(){
# 	qDebug()<<"V11 pressed.";
# }
# void VentilsGui::bV12Clicked(){
# 	qDebug()<<"V12 pressed.";
# }
#
# *****************************
# Slot definitions
# *****************************
#
# void bV1Clicked();
#
# void bV2Clicked();
#
# void bV3Clicked();
#
# void bV4Clicked();
#
# void bV5Clicked();
#
# void bV6Clicked();
#
# void bV7Clicked();
#
# void bV8Clicked();
#
# void bV9Clicked();
#
# void bV10Clicked();
#
# void bV11Clicked();
#
# void bV12Clicked();
